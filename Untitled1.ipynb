# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm) (1.16.3)

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.metrics import ndcg_score
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

queries = ["laptop", "phone", "headphones"]
docs_per_query = 15

data = []

for qid, query in enumerate(queries):
    for doc_id in range(docs_per_query):
        click = np.random.choice([0,1], p=[0.4,0.6])
        dwell_time = np.random.randint(5, 300) if click else np.random.randint(1, 10)
        relevance = click * (dwell_time / 300)

        data.append([
            qid, query, f"doc_{doc_id}",
            click, dwell_time, relevance
        ])

df = pd.DataFrame(data, columns=[
    "query_id", "query", "doc_id",
    "click", "dwell_time", "relevance"
])

df.head()
# Out:
#    query_id   query doc_id  click  dwell_time  relevance
# 0         0  laptop  doc_0      0           8   0.000000
# 1         0  laptop  doc_1      1         107   0.356667
# 2         0  laptop  doc_2      1         219   0.730000
# 3         0  laptop  doc_3      0           8   0.000000
# 4         0  laptop  doc_4      0           8   0.000000

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm) (1.16.3)

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.metrics import ndcg_score

# %%
np.random.seed(42)

queries = ["red dress", "black shoes", "blue jeans"]
products_per_query = 15

data = []

for qid, query in enumerate(queries):
    for pid in range(products_per_query):
        price = np.random.randint(500, 5000)
        rating = np.random.uniform(2, 5)

        click = np.random.choice([0,1], p=[0.5,0.5])
        add_to_cart = np.random.choice([0,1], p=[0.7,0.3]) if click else 0
        purchase = np.random.choice([0,1], p=[0.85,0.15]) if add_to_cart else 0

        dwell_time = np.random.randint(5, 300) if click else np.random.randint(1, 10)

        relevance = (
            0.3 * click +
            0.3 * add_to_cart +
            0.4 * purchase +
            0.001 * dwell_time
        )

        data.append([
            qid, query, f"product_{pid}",
            price, rating,
            click, add_to_cart, purchase,
            dwell_time, relevance
        ])

df = pd.DataFrame(data, columns=[
    "query_id", "query", "product_id",
    "price", "rating",
    "click", "add_to_cart", "purchase",
    "dwell_time", "relevance"
])

df.head()
# Out:
#    query_id      query product_id  price    rating  click  add_to_cart  \
# 0         0  red dress  product_0   1360  2.550304      1            0
# 1         0  red dress  product_1    966  2.299925      0            0
# 2         0  red dress  product_2   3671  2.428600      1            0
# 3         0  red dress  product_3   2933  2.545475      0            0
# 4         0  red dress  product_4   3404  2.873687      1            0
#
#    purchase  dwell_time  relevance
# 0         0         126      0.426
# 1         0           5      0.005
# 2         0         298      0.598
# 3         0           6      0.006
# 4         0         192      0.492

# %%
df["normalized_price"] = df["price"] / df["price"].max()
df["ctr"] = df.groupby("query")["click"].transform("mean")

features = [
    "price", "rating",
    "click", "add_to_cart", "purchase",
    "dwell_time", "normalized_price", "ctr"
]

X = df[features]
y = df["relevance"]

group = df.groupby("query_id").size().to_list()

# %%
model = lgb.LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    n_estimators=50
)

# Convert continuous relevance scores to integer labels for LightGBM Ranker
# Scale 'y' values to an integer range (e.g., 0-4) and convert to int type
y_int = (y / y.max() * 4).round().astype(int)

model.fit(X, y_int, group=group)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000146 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 64
# [LightGBM] [Info] Number of data points in the train set: 45, number of used features: 5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRanker(metric='ndcg', n_estimators=50, objective='lambdarank')

# %%
df["score"] = model.predict(X)

ranked = df.sort_values(
    ["query", "score"],
    ascending=[True, False]
)

ranked[["query", "product_id", "score"]].head(15)
# Out:
#           query  product_id     score
# 16  black shoes   product_1  0.351829
# 24  black shoes   product_9  0.351829
# 27  black shoes  product_12  0.351829
# 18  black shoes   product_3  0.255797
# 28  black shoes  product_13 -0.173891
# 25  black shoes  product_10 -0.195611
# 17  black shoes   product_2 -0.202467
# 20  black shoes   product_5 -0.202467
# 21  black shoes   product_6 -0.202467
# 19  black shoes   product_4 -0.259325
# 22  black shoes   product_7 -0.259325
# 29  black shoes  product_14 -0.351501
# 23  black shoes   product_8 -0.408359
# 26  black shoes  product_11 -0.456720
# 15  black shoes   product_0 -0.520433

# %%
true_rel = df["relevance"].values.reshape(1, -1)
pred_rel = df["score"].values.reshape(1, -1)

print("NDCG:", ndcg_score(true_rel, pred_rel))
# Out:
# NDCG: 0.8566405830970373

# %%
ranked = df.sort_values(
    ["query", "score"],
    ascending=[True, False]
)

# %%
ranked.head(20)
# Out:
#     query_id        query  product_id  price    rating  click  add_to_cart  \
# 16         1  black shoes   product_1    891  4.187022      1            0
# 24         1  black shoes   product_9   1559  4.828561      1            0
# 27         1  black shoes  product_12   2481  3.618027      1            1
# 18         1  black shoes   product_3   2954  4.006524      1            0
# 28         1  black shoes  product_13   1806  3.281323      1            1
# 25         1  black shoes  product_10   3125  3.873062      0            0
# 17         1  black shoes   product_2   3599  4.589310      1            0
# 20         1  black shoes   product_5   4340  4.165189      0            0
# 21         1  black shoes   product_6   4988  4.131989      0            0
# 19         1  black shoes   product_4   2070  3.416645      0            0
# 22         1  black shoes   product_7   1363  3.909231      0            0
# 29         1  black shoes  product_14   4913  2.666323      0            0
# 23         1  black shoes   product_8   2257  2.417994      1            0
# 26         1  black shoes  product_11   3193  3.369604      0            0
# 15         1  black shoes   product_0   2527  2.880465      0            0
# 37         2   blue jeans   product_7   2827  3.410902      1            0
# 38         2   blue jeans   product_8   1108  2.452153      1            0
# 35         2   blue jeans   product_5   3974  4.042116      1            0
# 43         2   blue jeans  product_13   4143  2.782488      1            1
# 41         2   blue jeans  product_11   3476  3.192716      1            1
#
#     purchase  dwell_time  relevance  normalized_price       ctr     score
# 16         0         235      0.535          0.178629  0.466667  0.351829
# 24         0         288      0.588          0.312550  0.466667  0.351829
# 27         0         229      0.829          0.497394  0.466667  0.351829
# 18         0         218      0.518          0.592221  0.466667  0.255797
# 28         0         141      0.741          0.362069  0.466667 -0.173891
# 25         0           5      0.005          0.626504  0.466667 -0.195611
# 17         0          52      0.352          0.721532  0.466667 -0.202467
# 20         0           7      0.007          0.870088  0.466667 -0.202467
# 21         0           3      0.003          1.000000  0.466667 -0.202467
# 19         0           3      0.003          0.414996  0.466667 -0.259325
# 22         0           4      0.004          0.273256  0.466667 -0.259325
# 29         0           8      0.008          0.984964  0.466667 -0.351501
# 23         0          33      0.333          0.452486  0.466667 -0.408359
# 26         0           4      0.004          0.640136  0.466667 -0.456720
# 15         0           3      0.003          0.506616  0.466667 -0.520433
# 37         0         244      0.544          0.566760  0.333333  0.520409
# 38         0         263      0.563          0.222133  0.333333  0.202796
# 35         0         202      0.502          0.796712  0.333333  0.144075
# 43         0         164      0.764          0.830593  0.333333 -0.004958
# 41         0         155      0.755          0.696872  0.333333 -0.117033

# %%
query_example = "red dress"

result = ranked[ranked["query"] == query_example]

result[["product_id", "price", "rating", "score"]].head(10)
# Out:
#     product_id  price    rating     score
# 7    product_7   3388  2.195155  0.266509
# 2    product_2   3671  2.428600  0.259653
# 11  product_11   4343  2.554563  0.259653
# 4    product_4   3404  2.873687 -0.110177
# 9    product_9   3056  4.499585 -0.195611
# 3    product_3   2933  2.545475 -0.239779
# 6    product_6   2399  3.542703 -0.259325
# 13  product_13    837  3.619076 -0.259325
# 8    product_8   3112  2.692681 -0.344645
# 12  product_12   3842  2.265478 -0.351501

# %%
import matplotlib.pyplot as plt

top10 = result.head(10)

plt.figure(figsize=(8,5))
plt.barh(top10["product_id"], top10["score"])
plt.gca().invert_yaxis()
plt.title("Top Ranked Products for 'red dress'")
plt.xlabel("Score")
plt.show()

# %%
# Before ranking (random)
original = df[df["query"] == "red dress"].head(10)

print("Before Ranking:")
print(original[["product_id", "relevance"]])

print("\nAfter Ranking:")
print(result[["product_id", "score"]].head(10))
# Out:
# Before Ranking:
#   product_id  relevance
# 0  product_0      0.426
# 1  product_1      0.005
# 2  product_2      0.598
# 3  product_3      0.006
# 4  product_4      0.492
# 5  product_5      0.003
# 6  product_6      0.439
# 7  product_7      0.869
# 8  product_8      0.007
# 9  product_9      0.001
#
# After Ranking:
#     product_id     score
# 7    product_7  0.266509
# 2    product_2  0.259653
# 11  product_11  0.259653
# 4    product_4 -0.110177
# 9    product_9 -0.195611
# 3    product_3 -0.239779
# 6    product_6 -0.259325
# 13  product_13 -0.259325
# 8    product_8 -0.344645
# 12  product_12 -0.351501
